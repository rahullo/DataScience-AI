# %%
import pandas as pd

# %%
df = pd.read_csv('weatherData.csv')

# %%
df.columns
# Out:
# Index(['Date', 'Station_Index_Number', 'Maximum Temperature (°C)',
#        'Minimum Temperature (°C)', 'Rainfall (mm)'],
#       dtype='object')

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['Maximum Temperature (°C)'].plot()
# Out:
# <AxesSubplot:>

# %%
df['Minimum Temperature (°C)'].plot(legend=True)
# Out:
# <AxesSubplot:>

# %%
df.plot(x='Minimum Temperature (°C)', y='Maximum Temperature (°C)', kind='scatter', legend=True)
# Out:
# <AxesSubplot:xlabel='Minimum Temperature (°C)', ylabel='Maximum Temperature (°C)'>

# %%
df.plot(title='sample Plot', figsize=(15,10))
# Out:
# <AxesSubplot:title={'center':'sample Plot'}>

# %%
df['Maximum Temperature (°C)'].plot(kind='box', title='Box Plot')
# Out:
# <AxesSubplot:title={'center':'Box Plot'}>

# %%
df['Maximum Temperature (°C)'].plot(kind='hist', title='histogram Plot')
# Out:
# <AxesSubplot:title={'center':'histogram Plot'}, ylabel='Frequency'>
