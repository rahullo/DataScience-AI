# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data/FAMILY_DATA.csv')

# %%
data['NAME'] = data['NAME'].str.capitalize()

# %%
data
# Out:
#           NAME  AGE  HIEGHT(CM)  WIEGHT
# 0      Chandan   22         155      75
# 1     Yashwant   24         153      65
# 2        Yash    15         140      70
# 3        Bhola   23         135      60
# 4       Chetan   21         158      75
# 5      Shridhi   15         130      60
# 6      Nandani   19         153      56
# 7   Deepshikha   22         148      63
# 8        Astha   15         138      51
# 9       Nikhil   12         139      50
# 10     Shivjal   13         135      48
# 11        Neha   26         145      55
# 12       Rahul   24         152      72

# %%
plt.barh(data['NAME'], data['AGE'])
# Out:
# <BarContainer object of 13 artists>
