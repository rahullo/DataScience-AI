# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('data/MCA_Student.xlsx')
pd.set_option('display.max_rows', len(data))
pd.set_option('display.max_columns', None)
data
# Out:
#    Exam Roll No.          Student's Name  SEM_1_SGPA
# 0    23419MCA001                  AAKASH        6.00
# 1    23419MCA002            ABHAY  YADAV        6.65
# 2    23419MCA003         ABHISHEK  KUMAR        7.20
# 3    23419MCA004        ABHISHEK  RANJAN        8.05
# 4    23419MCA005   ABHISHEK KUMAR SHUKLA         NaN
# 5    23419MCA006           ADITI  SHARMA        6.20
# 6    23419MCA007       AKASH KUMAR MAURY        8.80
# 7    23419MCA008         AKSHAT  JAISWAL         NaN
# 8    23419MCA009        AKSHAY  BHANDARI        5.50
# 9    23419MCA010    AKSHAY KUMAR DIWAKAR         NaN
# 10   23419MCA011           AMIT  DWIVEDI        7.80
# 11   23419MCA012            ANISH  KUMAR         NaN
# 12   23419MCA013         ANJEET  KESHARI        8.55
# 13   23419MCA014             ANUJ  KUMAR        6.65
# 14   23419MCA015            ARPIT   SAHU         NaN
# 15   23419MCA017           AYUSH  SHARMA        7.80
# 16   23419MCA018            AYUSH  VERMA         NaN
# ...

# %%
pd.set_option('display.max_rows', len(sorted_data))
pd.set_option('display.max_columns', None)

sorted_data = data.sort_values(by='SEM_1_SGPA', ascending=False)
sorted_data = sorted_data.reset_index(drop=True)
sorted_data
# Out:
#    Exam Roll No.          Student's Name  SEM_1_SGPA
# 0    23419MCA007       AKASH KUMAR MAURY        8.80
# 1    23419MCA059      SUDHANSHU  SHEKHAR        8.55
# 2    23419MCA013         ANJEET  KESHARI        8.55
# 3    23419MCA056           SOUMENDU  ROY        8.45
# 4    23419MCA066    MANISH PRASAD SHARMA        8.15
# 5    23419MCA046         SAGAR  PURSWANI        8.10
# 6    23419MCA004        ABHISHEK  RANJAN        8.05
# 7    23419MCA061            UTKARSH  PAL        8.00
# 8    23419MCA047         SAKSHAM  TOLANI        7.90
# 9    23419MCA062           VATSAL  SINGH        7.85
# 10   23419MCA032          KHUSHI  JONWAL        7.85
# 11   23419MCA017           AYUSH  SHARMA        7.80
# 12   23419MCA011           AMIT  DWIVEDI        7.80
# 13   23419MCA019                  BHARAT        7.65
# 14   23419MCA049            SANDEEP  RAJ        7.65
# 15   23419MCA042          RAJESH  PANDIT        7.60
# 16   23419MCA053           SHWETA  SINGH        7.45
# ...

# %%
sorted_data.to_csv('student_output_file.csv', index=True)

# %%
pd.set_option('display.max_rows', len(sorted_data))
pd.set_option('display.max_columns', None)

# %%
sorted_data
# Out:
#    Exam Roll No.          Student's Name  SEM_1_SGPA
# 0    23419MCA007       AKASH KUMAR MAURY        8.80
# 1    23419MCA059      SUDHANSHU  SHEKHAR        8.55
# 2    23419MCA013         ANJEET  KESHARI        8.55
# 3    23419MCA056           SOUMENDU  ROY        8.45
# 4    23419MCA066    MANISH PRASAD SHARMA        8.15
# 5    23419MCA046         SAGAR  PURSWANI        8.10
# 6    23419MCA004        ABHISHEK  RANJAN        8.05
# 7    23419MCA061            UTKARSH  PAL        8.00
# 8    23419MCA047         SAKSHAM  TOLANI        7.90
# 9    23419MCA062           VATSAL  SINGH        7.85
# 10   23419MCA032          KHUSHI  JONWAL        7.85
# 11   23419MCA017           AYUSH  SHARMA        7.80
# 12   23419MCA011           AMIT  DWIVEDI        7.80
# 13   23419MCA019                  BHARAT        7.65
# 14   23419MCA049            SANDEEP  RAJ        7.65
# 15   23419MCA042          RAJESH  PANDIT        7.60
# 16   23419MCA053           SHWETA  SINGH        7.45
# ...

# %%
x = sorted_data['Exam Roll No.']
y = sorted_data['SEM_1_SGPA']

plt.scatter(x, y)
