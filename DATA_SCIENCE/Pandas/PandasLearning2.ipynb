# %%
import pandas as pd

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0],
                 index=['a', 'b', 'c', 'd'])
data.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
data['c']
# Out:
# 0.75

# %%
'a' in data
# Out:
# True
