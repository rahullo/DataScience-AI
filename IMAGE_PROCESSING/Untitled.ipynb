# %%
# !pip install opencv-python
import cv2

# %%
g_image = cv2.imread('./IMAGES/Gbaboon.jpg', cv2.IMREAD_GRAYSCALE)
c_image = cv2.imread('./IMAGES/Cbaboon.tiff')

# %%
print(list(g_image[0]))
# Out:
# [147, 58, 39, 96, 134, 87, 65, 31, 70, 77, 90, 143, 158, 103, 75, 144, 184, 117, 82, 94, 72, 91, 108, 62, 73, 117, 121, 67, 59, 142, 172, 65, 70, 136, 135, 90, 77, 55, 172, 87, 37, 69, 161, 157, 59, 110, 92, 123, 142, 106, 77, 116, 118, 110, 163, 181, 150, 97, 167, 158, 85, 160, 196, 122, 170, 131, 142, 144, 184, 158, 106, 156, 79, 66, 110, 117, 126, 107, 62, 124, 196, 157, 65, 68, 49, 36, 94, 83, 111, 91, 188, 202, 113, 67, 35, 53, 43, 119, 119, 91, 90, 117, 138, 100, 107, 152, 98, 151, 165, 137, 150, 101, 113, 162, 143, 162, 139, 123, 112, 68, 112, 159, 160, 129, 172, 170, 118, 203, 148, 173, 134, 190, 151, 131, 184, 170, 132, 53, 74, 111, 183, 88, 144, 178, 162, 106, 123, 162, 144, 166, 63, 58, 89, 106, 91, 54, 65, 105, 71, 47, 106, 76, 77, 139, 164, 74, 135, 95, 69, 53, 76, 105, 132, 127, 125, 108, 113, 156, 137, 160, 175, 148, 170, 93, 67, 97, 67, 145, 163, 60, 64, 64, 138, 178, 143, 66, 75, 142, 169, 168, 189, 181, 162, 132, 151, 158, 169, 160, 168, 133, 99, 114, 171, 149, 84, 
# ...

# %%
print(c_image.shape, g_image.shape)
print(c_image.dtype, g_image.dtype)
# Out:
# (512, 512, 3) (512, 512)
# uint8 uint8
